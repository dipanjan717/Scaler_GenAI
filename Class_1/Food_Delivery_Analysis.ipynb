# %%
import numpy as np

x= [1, "Suraaj", True, 10.33 ]

y = np.array([1, "Suraaj", True, 10.33 ])

y
# Out:
# array(['1', 'Suraaj', 'True', '10.33'], dtype='<U32')

# %%
z= np.array([1, True, 10.33 ])
z
# Out:
# array([ 1.  ,  1.  , 10.33])

# %%
s= np.array([1, True ])
s
# Out:
# array([1, 1])

# %%
[10,20,30,40,2,3,4,5,6] * 2
# Out:
# [10, 20, 30, 40, 2, 3, 4, 5, 6, 10, 20, 30, 40, 2, 3, 4, 5, 6]

# %%
c = [10,20,30,40,2,3,4,5,6]
d = []
for i in c:
  d.append(i*2)
d
# Out:
# [20, 40, 60, 80, 4, 6, 8, 10, 12]

# %%
np.array([10,20,30,40,2,3,4,5,6]) * 2
# Out:
# array([20, 40, 60, 80,  4,  6,  8, 10, 12])

# %%
np.array([10,20,30,40,2,3,4,5,6]) + np.array([10,20,30,40,2,3,4,5,6])
# Out:
# array([20, 40, 60, 80,  4,  6,  8, 10, 12])

# %%
f = [10,20,30,40,2,3,4,5,6] + [10,20,30,40,2,3,4,5,6]

# %%
g = np.array(f)
g
# Out:
# array([10, 20, 30, 40,  2,  3,  4,  5,  6, 10, 20, 30, 40,  2,  3,  4,  5,
#         6])

# %%
g.shape
# Out:
# (18,)

# %%
print(g.ndim)

print(g.size)
# Out:
# 1
# 18

# %%
h = g.astype(str)
g.dtype
# Out:
# dtype('int64')

# %%
h.dtype
# Out:
# dtype('<U21')

# %%
votes=[778,550,650,780,800,900,1000]
cost=[2000,1500,1000,600,2000,400,500]

details = np.array(votes,cost)

details
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_287/3373556506.py in <cell line: 0>()
#       2 cost=[2000,1500,1000,600,2000,400,500]
#       3
# ----> 4 details = np.array(votes,cost)
#       5
#       6 details
#
# TypeError: Field elements must be 2- or 3-tuples, got '2000'
