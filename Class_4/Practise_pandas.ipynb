# %%
import pandas as pd

# %%
# Downloading and unzipping the dataset
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# !unzip zomato_dataset.zip
# !mv zomato_dataset.csv.
# Out:
# --2026-04-02 14:19:17--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 3.169.117.63, 3.169.117.64, 3.169.117.127, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|3.169.117.63|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72602133 (69M) [application/zip]
# Saving to: ‘zomato_dataset.zip’
#
# zomato_dataset.zip  100%[===================>]  69.24M  66.3MB/s    in 1.0s
#
# 2026-04-02 14:19:19 (66.3 MB/s) - ‘zomato_dataset.zip’ saved [72602133/72602133]
#
# Archive:  zomato_dataset.zip
#   inflating: zomato_dataset.csv
# mv: missing destination file operand after 'zomato_dataset.csv.'
# Try 'mv --help' for more information.

# %%
df= pd.read_csv("/content/zomato_dataset.csv")

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.tail(10)
# Out:
#                                                      url  \
# 23183  https://www.zomato.com/bangalore/bar-bar-white...
# 23184  https://www.zomato.com/bangalore/the-beer-cafe...
# 23185  https://www.zomato.com/bangalore/pablos-gastro...
# 23186  https://www.zomato.com/bangalore/olivers-pub-d...
# 23187  https://www.zomato.com/bangalore/smaaash-white...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 23183  Level 2, Phoenix Marketcity, Whitefield, Banga...
# 23184  Unit 4A - 4B, Upper Ground Floor, VR Bengaluru...
# 23185  2, Graphite India Road, Doddanekundi Industria...
# 23186  ITPL Ascendas Park Square Mall, ITPL, First Fl...
# ...

# %%
df.iloc[100]
# Out:
# url                            https://www.zomato.com/bangalore/chutney-chang...
# address                        Cosmopolitan Club, 22nd Cross, 3rd Block, Jaya...
# name                                                               Chutney Chang
# online_order                                                                 Yes
# book_table                                                                   Yes
# rate                                                                       4.1/5
# votes                                                                       2339
# phone                                             080 22443007\r\n+91 9901967373
# location                                                               Jayanagar
# rest_type                                                          Casual Dining
# dish_liked                     Veg Momos, Brownie Chocolate, Palak Chaat, Mut...
# cuisines                                              North Indian, Chinese, BBQ
# ...

# %%
df.iloc[1:4]
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
#
#                                              address                   name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
#
#   online_order book_table   rate  votes           phone      location  \
# 1          Yes         No  4.1/5    787    080 41714161  Banashankari
# 2          Yes         No  3.8/5    918  +91 9663487993  Banashankari
# 3           No         No  3.7/5     88  +91 9620009302  Banashankari
#
#              rest_type                                         dish_liked  \
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# ...

# %%
df.iloc[1:9:3]
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 4  https://www.zomato.com/bangalore/grand-village...
# 7  https://www.zomato.com/bangalore/penthouse-caf...
#
#                                              address            name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...   Grand Village
# 7  1, 30th Main Road, 3rd Stage, Banashankari, Ba...  Penthouse Cafe
#
#   online_order book_table   rate  votes                             phone  \
# 1          Yes         No  4.1/5    787                      080 41714161
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
# 7          Yes         No  4.0/5    324  +91 8884135549\r\n+91 9449449316
#
#        location      rest_type  \
# 1  Banashankari  Casual Dining
# 4  Basavanagudi  Casual Dining
# 7  Banashankari           Cafe
#
# ...

# %%
df_explicit = df.set_index("name")

# %%
df_explicit
# Out:
#                                                                                                   url  \
# name
# Jalsa                                               https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant                                      https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe                                     https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana                               https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village                                       https://www.zomato.com/bangalore/grand-village...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  https://www.zomato.com/bangalore/izakaya-gastr...
# M Bar - Bengaluru Marriott Hotel Whitefield         https://www.zomato.com/bangalore/m-bar-bengalu...
# ...

# %%
df_explicit.loc["Jalsa"]
# Out:
#                                                      url  \
# name
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
#
#                                                  address online_order  \
# name
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# ...

# %%
df_explicit.reset_index(inplace=True)

# %%
df_explicit
# Out:
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# 3                                  Addhuri Udupi Bhojana
# 4                                          Grand Village
# ...                                                  ...
# 23188                                 Izakaya Gastro Pub
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield
# 23190                             Keys Cafe - Keys Hotel
# 23191                                            Bhagini
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...
#
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# ...

# %%
df.describe()
# Out:
#               votes
# count  23193.000000
# mean     601.074462
# std     1114.854301
# min        0.000000
# 25%      101.000000
# 50%      221.000000
# 75%      586.000000
# max    16832.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   rate                         23193 non-null  object
#  6   votes                        23193 non-null  int64
#  7   phone                        23193 non-null  object
#  8   location                     23193 non-null  object
#  9   rest_type                    23193 non-null  object
#  10  dish_liked                   23193 non-null  object
#  11  cuisines                     23193 non-null  object
#  12  approx_cost(for two people)  23193 non-null  object
# ...

# %%
df.shape
# Out:
# (23193, 17)

# %%
hahaha = df.iloc[100]

# %%
hahaha.shape
# Out:
# (17,)

# %%
data = {
    "Restaurant": ["R1", "R2", "R3"],
    "Votes": [120, 240, 150],
    "Rating": [4.1, 4.5, 3.9]
}

# %%
pd.DataFrame(data)
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9

# %%
import numpy as np
ratings = np.array([4.1, 4.5, 3.9])

# %%
Se = pd.Series(ratings)

# %%
de = pd.DataFrame(ratings)

# %%
Se.shape
# Out:
# (3,)

# %%
de.shape
# Out:
# (3, 1)

# %%
df["name"]
# Out:
# 0                                                    Jalsa
# 1                                           Spice Elephant
# 2                                          San Churro Cafe
# 3                                    Addhuri Udupi Bhojana
# 4                                            Grand Village
#                                ...
# 23188                                   Izakaya Gastro Pub
# 23189          M Bar - Bengaluru Marriott Hotel Whitefield
# 23190                               Keys Cafe - Keys Hotel
# 23191                                              Bhagini
# 23192    Chime - Sheraton Grand Bengaluru Whitefield Ho...
# Name: name, Length: 23193, dtype: object

# %%
df[["name","rate"]]
# Out:
#                                                     name    rate
# 0                                                  Jalsa   4.1/5
# 1                                         Spice Elephant   4.1/5
# 2                                        San Churro Cafe   3.8/5
# 3                                  Addhuri Udupi Bhojana   3.7/5
# 4                                          Grand Village   3.8/5
# ...                                                  ...     ...
# 23188                                 Izakaya Gastro Pub  3.8 /5
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield  3.9 /5
# 23190                             Keys Cafe - Keys Hotel  2.8 /5
# 23191                                            Bhagini  2.5 /5
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...  4.3 /5
#
# [23193 rows x 2 columns]

# %%
df.rename(columns = {'rate':'ratings'},inplace=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table ratings  votes                             phone  \
# 0          Yes        Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df['ratings']= df['ratings'].replace('NEW','4.0/5')

# %%
df['ratings'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '4.6/5', '4.0/5', '4.2/5', '3.9/5',
#        '3.0/5', '3.6/5', '2.8/5', '4.4/5', '3.1/5', '4.3/5', '2.6/5',
#        '3.3/5', '3.5/5', '3.8 /5', '3.2/5', '4.5/5', '2.5/5', '2.9/5',
#        '3.4/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '4.8/5',
#        '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5', '2.7 /5',
#        '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5', '4.4 /5',
#        '4.9/5', '2.1/5', '2.0/5', '1.8/5', '3.4 /5', '3.6 /5', '3.3 /5',
#        '4.6 /5', '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5', '3.5 /5',
#        '3.1 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df['ratings']= df['ratings'].str[:3].astype(float)

# %%
df.describe()
# Out:
#             ratings         votes
# count  23193.000000  23193.000000
# mean       3.904989    601.074462
# std        0.425079   1114.854301
# min        1.800000      0.000000
# 25%        3.800000    101.000000
# 50%        4.000000    221.000000
# 75%        4.200000    586.000000
# max        4.900000  16832.000000

# %%
df.to_csv('cleaned_data.csv')

# %%
df.iloc[0:2,0:2]
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...

# %%
df.iloc[-2:-1]
# Out:
#                                                      url  \
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
#
#                                                  address     name  \
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...  Bhagini
#
#       online_order book_table  ratings  votes         phone    location  \
# 23191           No         No      2.5     81  080 65951222  Whitefield
#
#                 rest_type            dish_liked  \
# 23191  Casual Dining, Bar  Biryani, Andhra Meal
#
#                                           cuisines  \
# 23191  Andhra, South Indian, Chinese, North Indian
#
#       approx_cost(for two people)  \
# 23191                     '800.0'
#
#                                             reviews_list menu_item  \
# 23191  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
#
#       listed_in(type) listed_in(city)
# 23191   Pubs and bars      Whitefield

# %%
df['flag'] = 1

# %%
df_explicit = df.set_index("name")

df_explicit.loc[["Jalsa", "Grand Village"], ["flag"]]
# Out:
#                flag
# name
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Jalsa             1
# Grand Village     1
# Grand Village     1
# Grand Village     1
# Grand Village     1

# %%
df_explicit.loc["Jalsa","flag"]=0

# %%
df_explicit
# Out:
#                                                                                                   url  \
# name
# Jalsa                                               https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant                                      https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe                                     https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana                               https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village                                       https://www.zomato.com/bangalore/grand-village...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  https://www.zomato.com/bangalore/izakaya-gastr...
# M Bar - Bengaluru Marriott Hotel Whitefield         https://www.zomato.com/bangalore/m-bar-bengalu...
# ...

# %%
df_explicit.loc[df_explicit["votes"]>500, "flag"] = -1

# %%
df_explicit
# Out:
#                                                                                                   url  \
# name
# Jalsa                                               https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant                                      https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe                                     https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana                               https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village                                       https://www.zomato.com/bangalore/grand-village...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  https://www.zomato.com/bangalore/izakaya-gastr...
# M Bar - Bengaluru Marriott Hotel Whitefield         https://www.zomato.com/bangalore/m-bar-bengalu...
# ...

# %%
data1 = {
    "Restaurant": ["R1", "R2", "R3", "R4"],
    "Votes": [120, 240, 150, 80],
    "Rating": [4.1, 4.5, 3.9, 4.0]
}


data2 = {
    "Restaurant": ["R5", "R6"],
    "Votes": [90, 110],
    "Rating": [3.8, 4.3]
}


df1= pd.DataFrame(data1)
df2= pd.DataFrame(data2)

# %%
df1
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R4     80     4.0

# %%
df2
# Out:
#   Restaurant  Votes  Rating
# 0         R5     90     3.8
# 1         R6    110     4.3

# %%
final_df = pd.concat([df1,df2],axis=0)

final_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R4     80     4.0
# 0         R5     90     3.8
# 1         R6    110     4.3

# %%
final_df = pd.concat([df1,df2], axis=0).reset_index(drop=True)

final_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R4     80     4.0
# 4         R5     90     3.8
# 5         R6    110     4.3

# %%
new_columns = {
    "Delivery Time (mins)": [30, 25, 35, 20, 40, 28]
}

new_df= pd.DataFrame(new_columns)

# %%
new_df
# Out:
#    Delivery Time (mins)
# 0                    30
# 1                    25
# 2                    35
# 3                    20
# 4                    40
# 5                    28

# %%
pd.concat([final_df,new_df],axis=1)
# Out:
#   Restaurant  Votes  Rating  Delivery Time (mins)
# 0         R1    120     4.1                    30
# 1         R2    240     4.5                    25
# 2         R3    150     3.9                    35
# 3         R4     80     4.0                    20
# 4         R5     90     3.8                    40
# 5         R6    110     4.3                    28

# %%
##########
data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1"],
    "Votes": [120, 240, 150, 240, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.1]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
# Can I take tontal number of votes directly?

#Data wrangling or preparing your data for modeling.

################# To identify ####################

sample_df.duplicated(keep='first')

#sample_df.duplicated(keep='last')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sample_df.drop_duplicates(keep='first',inplace=True)

sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
sample_df.loc[sample_df["Votes"]>=150, "Rating"] = 4.2

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.2
# 2         R3    150     4.2
# 4         R4     80     4.0

# %%
sample_df.drop_duplicates(subset=['Rating'], keep='first', inplace=True)

# %%
sample_df.sort_values(by=["Votes","Rating"], ascending=[True, False])
# Out:
#   Restaurant  Votes  Rating
# 4         R4     80     4.0
# 0         R1    120     4.1
# 1         R2    240     4.2

# %%
sample_df.sort_values(by=["Votes"], ascending=[True])
# Out:
#   Restaurant  Votes  Rating
# 4         R4     80     4.0
# 0         R1    120     4.1
# 1         R2    240     4.2
